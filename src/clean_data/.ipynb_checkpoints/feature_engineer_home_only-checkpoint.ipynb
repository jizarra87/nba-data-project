# %%
import pandas as pd 

df = pd.read_csv('/home/ji/NBA_Project/data/data_cleaned_02_03_2025.csv')
df.head()
# Out:
#    PTS_LAST5_away  FGM_LAST5_away  FGA_LAST5_away  FG_PCT_LAST5_away  \
# 0           105.4            36.8            81.0             0.4552
# 1           107.6            37.8            78.8             0.4814
# 2           106.0            38.2            80.4             0.4782
# 3           103.6            37.8            83.0             0.4578
# 4           105.4            36.8            79.2             0.4644
#
#    FG3M_LAST5_away  FG3A_LAST5_away  FG3_PCT_LAST5_away  FTM_LAST5_away  \
# 0             10.0             27.6              0.3616            21.8
# 1             10.0             23.8              0.4216            22.0
# 2              9.4             23.4              0.4042            20.2
# 3             10.0             24.4              0.4128            18.0
# 4             10.4             26.0              0.4032            21.4
#
#    FTA_LAST5_away  FT_PCT_LAST5_away  ...  OREB_LAST5_home  DREB_LAST5_home  \
# ...

# %%
pd.set_option('display.max_info_columns', 40)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13628 entries, 0 to 13627
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PTS_LAST5_away         13628 non-null  float64
#  1   FGM_LAST5_away         13628 non-null  float64
#  2   FGA_LAST5_away         13628 non-null  float64
#  3   FG_PCT_LAST5_away      13628 non-null  float64
#  4   FG3M_LAST5_away        13628 non-null  float64
#  5   FG3A_LAST5_away        13628 non-null  float64
#  6   FG3_PCT_LAST5_away     13628 non-null  float64
#  7   FTM_LAST5_away         13628 non-null  float64
#  8   FTA_LAST5_away         13628 non-null  float64
#  9   FT_PCT_LAST5_away      13628 non-null  float64
#  10  OREB_LAST5_away        13628 non-null  float64
#  11  DREB_LAST5_away        13628 non-null  float64
#  12  REB_LAST5_away         13628 non-null  float64
#  13  AST_LAST5_away         13628 non-null  float64
# ...
